# %% [markdown]
# <a href="https://colab.research.google.com/github/yahavan/me526_assignments/blob/main/assignment1_basic_notions_of_probability.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Q1) 1.

# %%
# Q1) 1.
disk_radius = 10
total_area = math.pi * disk_radius**2
event_area = total_area - math.pi * (disk_radius - 1)**2
P_A = event_area / total_area
print(P_A)
# Out:
# 0.19000000000000006

# %% [markdown]
# ## Q1) 2.

# %%
# Q1) 2.
import math
disk_range = 10
event_range = 10 - 9
P_A = event_range / disk_range
print(P_A)
# Out:
# 0.1

# %% [markdown]
# ## Q1) 3.
# When choosing the probability based on Area, the outer rings have more area and the point is more probable to land further away. But when we choose uniformly by radius the point is equally likely to land anywhere along the radius.

# %% [markdown]
#  #
#  ![image.png](data:image/png;base64,...)

# %% [markdown]
# ##For an equilateral triangle inscribed in a circle with radius `R`:
#
# 1.  **Side length (`s`) of the equilateral triangle:**
#     `s = R * sqrt(3)`
#
# 2.  **Radius of the inscribed circle (inradius, `r`)** (i.e., the radius of the circle that is tangent to all three sides of the triangle):
#     `r = R / 2`

# %% [markdown]
# The idea behind this question is the same as in Q1. The question could be tackled two ways, considering the area, and considering the radius. When considering the area if the midpoint of the chord lies outside the inscribed circle the length of the chord is going to be smaller than the sidelenght of the inscribed triangle

# %% [markdown]
# ## Method 1: Considering the Area of the Midpoint
#
# For an equilateral triangle inscribed in a circle of radius `R`:
# *   The side length `s` is `R * sqrt(3)`.
# *   A chord will be longer than `s` if its midpoint falls within a concentric circle whose radius `r` is `R / 2` (this is the inradius of the inscribed equilateral triangle).
#
# Therefore, the probability is the ratio of the area of the inner circle (with radius `R/2`) to the area of the outer circle (with radius `R`).

# %%
import math

R = 10 # Let's assume a radius R for the main circle

# Radius of the inscribed circle (midpoints must fall within this)
inscribed_r = R / 2

# Area of the outer circle
total_area = math.pi * R**2

# Area of the inner circle (where chord midpoints result in longer chords)
event_area = math.pi * inscribed_r**2

P_area_method = event_area / total_area
print(f"Probability by Area Method: {P_area_method}")
# Out:
# Probability by Area Method: 0.25

# %% [markdown]
# ## Method 2: Considering a Point on a Radius
#
# Consider chords perpendicular to a fixed radius. The length of such a chord is `2 * sqrt(R^2 - d^2)`, where `d` is the distance of the chord's midpoint from the center.
#
# For the chord to be longer than the side of the inscribed equilateral triangle (`R * sqrt(3)`), we need:
# `2 * sqrt(R^2 - d^2) > R * sqrt(3)`
#
# Squaring both sides:
# `4 * (R^2 - d^2) > 3 * R^2`
# `4R^2 - 4d^2 > 3R^2`
# `R^2 > 4d^2`
# `R > 2d` (since R and d are positive)
# `d < R / 2`
#
# If we choose a point uniformly along a radius `R` (where `d` is the distance from the center), the probability that `d < R/2` is the ratio of the favorable range (`R/2`) to the total range (`R`).

# %%
R = 10 # Let's assume a radius R for the main circle

# Chords are longer if their midpoint distance 'd' from the center is less than R/2
event_range_d = R / 2

# Total possible range for 'd' is from 0 to R
total_range_d = R

P_radius_method = event_range_d / total_range_d
print(f"Probability by Radius Method: {P_radius_method}")
# Out:
# Probability by Radius Method: 0.5

# %% [markdown]
# # ![image.png](data:image/png;base64,...)

# %% [markdown]
# B is the event of both being girls. A is the event of having at least one girl
#
# Ω = {GG, GB, BG, BB}
#
# $P(B | A) = \frac{P(B \text{ and } A)}{P(A)}$
#
# $P(B | A) = \frac{1/4}{3/4}$
#
# $P(B | A) = \frac{1}{3}$

# %% [markdown]
# # ![image.png](data:image/png;base64,...)
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ##Q9)1.
# $\Omega = \{G_1, G_2, D_1, D_2\}$
#
# $\mathcal{F}$ contains $2^4$ elements.
#
# $\mathcal{F} = \{\emptyset, \{G_1\}, \{G_2\}, \dots, \{G_1, G_2\}, \dots, \Omega\}$
#
# $P(\{G_1\}) = 0.50, \quad P(\{G_2\}) = 0.20, \quad P(\{D_1\}) = 0.10, \quad P(\{D_2\}) = 0.20$

# %% [markdown]
# ##Q9)2.
#
# $\sigma(X) = \{\emptyset, \Omega, \{G_1, G_2\}, \{D_1, D_2\}\}$

# %% [markdown]
# ##Q9)3.
#
# $\sigma(Y) = \{\emptyset, \{G_1\}, \{G_2\}, \dots, \{G_1, G_2\}, \dots, \Omega\}$
#
# $\sigma(Y)$ is the power set.

# %% [markdown]
# ##Q9)4.
#
# We can see that $\sigma(Y)$ includes all the elements from $\sigma(X)$. Therefore $\sigma(X) \subseteq \sigma(Y)$.
#
# Since Y knows also knows from which machine the product is, while X lacks this information, Y is bigger than X.

# %% [markdown]
# ##Q9)5.
#
# $P(X=0) = P(\{G_1, G_2\}) = 0.50 + 0.20 = \mathbf{0.70}$
#
# $P(X=1) = P(\{D_1, D_2\}) = 0.10 + 0.20 = \mathbf{0.30}$

# %% [markdown]
# ##Q9)6.
#
# $P(Y=1) = \mathbf{0.50}$
#
# $P(Y=2) = \mathbf{0.20}$
#
# $P(Y=3) = \mathbf{0.10}$
#
# $P(Y=4) = \mathbf{0.20}$

# %% [markdown]
# ## Q9)7.
#
# $P(X=0, Y=1) = 0.50$
#
# $P(X=0, Y=2) = 0.20$
#
# $P(X=1, Y=3) = 0.10$
#
# $P(X=1, Y=4) = 0.20$

# %% [markdown]
# ##Q9)8.
# $P(X=1 | Y=3) = \frac{P(X=1, Y=3)}{P(Y=3)} = \frac{0.10}{0.10} = \mathbf{1}$
#
# $P(X=1 | Y=4) = \frac{0.20}{0.20} = \mathbf{1}$
#
# $P(Y=3 | X=1) = \frac{P(X=1, Y=3)}{P(X=1)} = \frac{0.10}{0.30} = \mathbf{\frac{1}{3} \approx 0.333}$
#
# $P(Y=4 | X=1) = \frac{P(X=1, Y=4)}{P(X=1)} = \frac{0.20}{0.30} = \mathbf{\frac{2}{3} \approx 0.667}$

# %% [markdown]
# ## Q9)9.
#
# When conditioning on Y, we have complete information whether the product is defective or good and from which machine the product originated.
#
# When conditioning on X, we only know whether the product is defective or not. When we get a defective product there would be $\frac{1}{3}$ chance of it having been from machine$1$ and $\frac{2}{3}$ chance of it having been from machine$2$.**bold text**

# %% [markdown]
# ##Q9)10.
#
# In $\sigma(X)$ but not $\sigma(Y)$: None
#
# In $\sigma(Y)$ but not $\sigma(X)$: Machine ID

# %% [markdown]
# ##Q9)11.

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# Define the Joint Probability Matrix
# Rows are X (0=Good, 1=Defective)
# Columns are Y (1=G1, 2=G2, 3=D1, 4=D2)
joint_probs = np.array([
    [0.50, 0.20, 0.00, 0.00],  # X = 0
    [0.00, 0.00, 0.10, 0.20]   # X = 1
])

# Plotting the heatmap
plt.figure(figsize=(8, 5))
sns.heatmap(joint_probs, annot=True, cmap="Blues", fmt=".2f",
            xticklabels=['Y=1 (G1)', 'Y=2 (G2)', 'Y=3 (D1)', 'Y=4 (D2)'],
            yticklabels=['X=0 (Good)', 'X=1 (Defective)'])

plt.title("Joint Probability Distribution of X and Y")
plt.xlabel("Random Variable Y (Quality & Machine)")
plt.ylabel("Random Variable X (Quality Only)")
plt.show()

# %% [markdown]
# ##Q9)12.
#
# Marginal Entropy of $X$ :
#
# $H(X) = -(0.7 \log_2 0.7 + 0.3 \log_2 0.3)$
#
# $H(X) \approx -(-0.360 + -0.521) = \mathbf{0.881 \text{ bits}}$
#
# Marginal Entropy of $Y$ :
#
# $H(Y) = -(0.5 \log_2 0.5 + 0.2 \log_2 0.2 + 0.1 \log_2 0.1 + 0.2 \log_2 0.2)$
#
# $H(Y) \approx -(-0.5 - 0.464 - 0.332 - 0.464) = \mathbf{1.760 \text{ bits}}$
#
# Conditional Entropy:
#
# $H(X|Y)$ (Uncertainty of $X$ given $Y$): $0$
#
# $H(Y|X)$ (Uncertainty of $Y$ given $X$):
#
# $H(Y|X) = H(X,Y) - H(X) = 1.760 - 0.881 = \mathbf{0.879 \text{ bits}}$
#
# Joint Entropy:
#
# $H(X, Y) = H(Y) = \mathbf{1.760 \text{ bits}}$

# %% [markdown]
# # ![image.png](data:image/png;base64,...)
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Q10)1.
#
# $\Omega = \mathbb{R}^2$
#
# $\mathfrak{F} = \mathfrak{B}(\mathbb{R}^2)$.
#
# $\mathbb{P}(A) = \iint_A \frac{1}{4\pi} \exp\left(-\frac{t^2}{2} - \frac{p^2}{8}\right) \, dt \, dp$

# %% [markdown]
# ##Q10)2.
#
# $\sigma(X) = \{ X^{-1}(B) : B \in \mathfrak{B}(\mathbb{R}) \} = \{ B \times \mathbb{R} : B \in \mathfrak{B}(\mathbb{R}) \}$

# %% [markdown]
# ##Q10)3.
#
# $\sigma(Y) = \{ Y^{-1}(A) : A \in \mathfrak{B}(\mathbb{R}^2) \} = \mathfrak{B}(\mathbb{R}^2)$

# %% [markdown]
# ##Q10)4.
# Any set in $\sigma(X)$ takes the form $B \times \mathbb{R}$
#
# Therefore, $B \times \mathbb{R} \in \mathfrak{B}(\mathbb{R}^2)$. Since $\mathfrak{B}(\mathbb{R}^2) = \sigma(Y)$, it follows that $\sigma(X) \subseteq \sigma(Y)$

# %% [markdown]
# ##Q10)5.
# $f_X(x) = \frac{1}{\sqrt{2\pi}} \exp\left(-\frac{x^2}{2}\right), \quad x \in \mathbb{R}$

# %% [markdown]
# ##Q10)6.
#
# $f_Y(t,p) = f_{T,P}(t,p) = \frac{1}{4\pi} \exp\left(-\frac{t^2}{2} - \frac{p^2}{8}\right), \quad (t,p) \in \mathbb{R}^2$

# %% [markdown]
# ##Q10)7.
#
# $\mathbb{P}(X \leq 0) = 0.5$
#
# $\mathbb{P}(X > 1) = 1 - \Phi(1) \approx 1 - 0.8413 = \textbf{0.1587}$
#
# $\mathbb{P}(Y \in (-\infty, 0] \times \mathbb{R}) = \mathbb{P}(T \leq 0) =$ $0.5$
#
# $\mathbb{P}(-1 \leq T \leq 1) \times \mathbb{P}(-2 \leq P \leq 2) = 0.6827 \times 0.6827 \approx \textbf{0.466}$

# %% [markdown]
# ##Q10)8.
# $\mathbb{P}(X = t \mid Y = (t,p)) = 1$

# %% [markdown]
# ##Q10)9.
# $\mathbb{P}(X = t \mid Y = (t,p)) = 1$

# %% [markdown]
# ##Q10)12.

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

# Setup grid for Y = (T, P)
t = np.linspace(-3, 3, 100)
p = np.linspace(-6, 6, 100)
T, P = np.meshgrid(t, p)

# Joint density of Y
# f_Y(t,p) = 1/(4*pi) * exp(-t^2/2 - p^2/8)
Z = (1 / (4 * np.pi)) * np.exp(- (T**2)/2 - (P**2)/8)

fig, axes = plt.subplots(1, 3, figsize=(18, 5))

# Plot 1: Joint density of Y (Contour)
contour = axes[0].contourf(T, P, Z, cmap='viridis')
axes[0].set_title('Joint Density of Y = (T,P)')
axes[0].set_xlabel('T (Temperature)')
axes[0].set_ylabel('P (Pressure)')
fig.colorbar(contour, ax=axes[0])

# Plot 2: Marginal density of X
x_vals = np.linspace(-3, 3, 100)
pdf_x = norm.pdf(x_vals, 0, 1) # Standard normal
axes[1].plot(x_vals, pdf_x, 'r-', lw=2)
axes[1].set_title('Marginal Density of X (T)')
axes[1].set_xlabel('X (Temperature)')
axes[1].set_ylabel('Density')

# Plot 3: Illustrating sigma-algebras
# sigma(X) are vertical strips, sigma(Y) are exact points
axes[2].set_xlim(-3, 3)
axes[2].set_ylim(-6, 6)
axes[2].axvspan(0.5, 1.5, color='blue', alpha=0.3, label='Set in $\sigma(X)$ (Know T only)')
axes[2].plot(1, 2, 'ro', label='Set in $\sigma(Y)$ (Know T and P)')
axes[2].set_title('$\sigma(X)$ vs $\sigma(Y)$ Resolution')
axes[2].set_xlabel('T')
axes[2].set_ylabel('P')
axes[2].legend()

plt.tight_layout()
plt.show()
# Out:
# <>:35: SyntaxWarning: invalid escape sequence '\s'
# <>:36: SyntaxWarning: invalid escape sequence '\s'
# <>:37: SyntaxWarning: invalid escape sequence '\s'
# <>:35: SyntaxWarning: invalid escape sequence '\s'
# <>:36: SyntaxWarning: invalid escape sequence '\s'
# <>:37: SyntaxWarning: invalid escape sequence '\s'
# /tmp/ipykernel_2402/2011200438.py:35: SyntaxWarning: invalid escape sequence '\s'
#   axes[2].axvspan(0.5, 1.5, color='blue', alpha=0.3, label='Set in $\sigma(X)$ (Know T only)')
# /tmp/ipykernel_2402/2011200438.py:36: SyntaxWarning: invalid escape sequence '\s'
#   axes[2].plot(1, 2, 'ro', label='Set in $\sigma(Y)$ (Know T and P)')
# /tmp/ipykernel_2402/2011200438.py:37: SyntaxWarning: invalid escape sequence '\s'
#   axes[2].set_title('$\sigma(X)$ vs $\sigma(Y)$ Resolution')
